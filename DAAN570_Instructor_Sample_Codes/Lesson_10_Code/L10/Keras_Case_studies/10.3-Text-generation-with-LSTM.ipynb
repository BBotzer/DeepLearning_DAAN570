# %% [markdown]
# # Text generation with LSTM
#
#
# [...]

# %% [markdown]
# ***Objectives***
#
# - Implementing character-level LSTM text generation
#
#
# Let's put these ideas in practice in a Keras implementation. The first thing we need is a lot of text data that we can use to learn a
# language model. You could use any sufficiently large text file or set of text files -- Wikipedia, the Lord of the Rings, etc.
#
# In this
# example we will use some of the writings of Nietzsche, the late-19th century German philosopher (translated to English). The language model
# we will learn will thus be specifically a model of Nietzsche's writing style and topics of choice, rather than a more generic model of the
# English language.

# %%
import tensorflow as tf
from tensorflow import keras
tf.__version__

# %% [markdown]
# ## Preparing the data
#
# Let's start by downloading the corpus and converting it to lowercase:

# %%
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))

# %% [markdown]
# Next, we will extract partially-overlapping sequences of length `maxlen`, one-hot encode them and pack them in a 3D Numpy array `x` of
# shape `(sequences, maxlen, unique_characters)`. Simultaneously, we prepare a array `y` containing the corresponding targets: the one-hot
# encoded characters that come right after each extracted sequence.

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=bool)
y = np.zeros((len(sentences), len(chars)), dtype=bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

# %% [markdown]
# ## Building the network
#
# Our network is a single `LSTM` layer followed by a `Dense` classifier and softmax over all possible characters. But let us note that
# recurrent neural networks are not the only way to do sequence data generation; 1D convnets also have proven extremely successful at it in
# recent times.

# %%
from tensorflow.keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %% [markdown]
# Since our targets are one-hot encoded, we will use `categorical_crossentropy` as the loss to train the model:

# %%
optimizer = keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the language model and sampling from it
#
#
# Given a trained model and a seed text snippet, we generate new text by repeatedly:
#
# * 1) Drawing from the model a probability distribution over the next character given the text available so far
# * 2) Reweighting the distribution to a certain "temperature"
# * 3) Sampling the next character at random according to the reweighted distribution
# * 4) Adding the new character at the end of the available text
#
# This is the code we use to reweight the original probability distribution coming out of the model,
# and draw a character index from it (the "sampling function"):

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Finally, this is the loop where we repeatedly train and generated text. We start generating text using a range of different temperatures
# after every epoch. This allows us to see how the generated text evolves as the model starts converging, as well as the impact of
# temperature in the sampling strategy.

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# 1565/1565 [==============================] - 138s 88ms/step - loss: 2.0324
# --- Generating with seed: "not ashamed of obscene thoughts, but they
# are ashamed when t"
# ------ temperature: 0.2
# not ashamed of obscene thoughts, but they
# are ashamed when the self-incertion of the spirit to the great in the greater the spirit to the complacually the great the greater that the great be the same the be self-inconcestion of the self to the spirit and interplation of the sach to the stand the greater of the same the self-inderent and stander the be something the same and still that the self-incertion of the something for the greater in the greater the r
# ------ temperature: 0.5
# ertion of the something for the greater in the greater the refured and itself, and species and something the religious proped to the grain that at their isperation, has be and concess
# to be in thus species him
# this to the one invere smands and the infellent in the lessible it is not which has must still which the demander the fremanted them time in the into not them conscies understreat the dountions of his desider of the spirit contraint in the severness
# ------ temperature: 1.0
# ons of his desider of the spirit contraint in the severness with over prekeve home ambeens and
# still our that is.=avition
# are, which
# things, streaging of
# teps horterare and howny hasder pleasure it
# greaps
# courted of
# aganshe, that felle of atit connuctith, have of gence to degrans ant himself. the conceit and indiestith
# to one shring and preids and altikes foramint all lings be heligater that sucr well ethdise found eastabredius are dearer
# moot
# infubled; wh
# ------ temperature: 1.2
# well ethdise found eastabredius are dearer
# moot
# infubled; what
# lomays
# let shameny it h, thinghrowg. hwand usfegle kant sime cimuics--for there
# somra east would, evep"tius all ammand, "them, comple ordogm. to pruilusts is eagrue mirin quest in
# unsiledphifing podent prailud an
#  s g touth egiously oblysjvoly,"
# se
# remprectisn. "to
#
# xxchide"phitiol dijalents trays it hespually knoble: they
#  he, anw what "tundly aeple dotest frurably  -amanisuerous
# complicnarg:
# epoch 2
# 1565/1565 [==============================] - 109s 70ms/step - loss: 1.6437
# --- Generating with seed: "he
# religious man as a lower and less valuable type, beyond, "
# ------ temperature: 0.2
# he
# religious man as a lower and less valuable type, beyond, the are the mankind the from the mankind and the expecience of the whole all the strong the supperity of the mankind the most far the man the spirit of the completent of the suffering the strong the strong the strong the depended the strong the species and the moral precearing the consequently the suffering and the are the the strong the spirit of the man the decearing the supperity of the conside
# ------ temperature: 0.5
# spirit of the man the decearing the supperity of the considerer and the men the did not of that who smell the deepinsed the depering that the supporing the sprect the deviled for all for the most many to be many as to the predifement in the determer of the oppenlent to the secrection, the prediness the sumpthy of the from the armong the can mankind the decigent the should that of the stranger and the weak of the far the are "good self the does not as the c
# ------ temperature: 1.0
# the weak of the far the are "good self the does not as the canaded, are extrakeade under,t "blorting of not arought dismens orginary highman nor persons "fargantly philosophy to
# that easol.
#
#
# 1ak
# =for from the conclum! to deepilation of his valus uam men first of health for the others up,
# the revalition--it gecevenise cmange--churally un, on e reminateagion
# of
# 8hher from it is modt have belieft tho and of agost must of the nyment the manned which refines o
# ------ temperature: 1.2
# o and of agost must of the nyment the manned which refines of the carts,-which is
# were perirad about he opination what,, the
# egedement vore, thing for songh matting if liment thst mobed instincts centuourthest from the crease-,,"  an.ever diknce. and gred from defther- fairing
# it
# from thatking, or erress of the sworr of
# men of the dfbrked to deelved sucus, as his indecution; the
# poste
# s1! if were he the blead mora whether even conguarly imnopention that
# th
# epoch 3
# 1565/1565 [==============================] - 106s 68ms/step - loss: 1.5368
# --- Generating with seed: "strengthen their own opinion of themselves by means of
# autho"
# ------ temperature: 0.2
# strengthen their own opinion of themselves by means of
# authorion of the most promise and the reason and the action of the strong and the more and the action of the reason the strong the greater the most the strong the command the manifessity of the stands to the most the stands the reason the strong the still and the greatest the stands to the greated the greated the greater the religions and the strong the decisely strong the stands the reason the decisel
# ------ temperature: 0.5
# strong the decisely strong the stands the reason the decisely a soul and for the action and the distruse of the being meanity and lack and the exualed in it has a man and romant to the most moral ever the realitional profement of experienced is learness of men which is the moralists and for over the hurtive it seems the dedemence of the decisely the greater and line something the words, no sprined inclination
# as the parations is still who has truth, and
# ar
# ------ temperature: 1.0
#  inclination
# as the parations is still who has truth, and
# arriving,
# interkrivit of morely sprectual time applannedus alpart, short, to comflured at it revect of e our forest endlyre again, the caluty. he
# philosophers the intruse.
# logy: are; the
# bleaded to portions, into he is suot more ppoily
# be strong
# ready
# because. the even which are of the stade to possed is
# strong peose of discompusional extrangoaced, his poopainw come long beli[fl-wordwers his jud in
# ------ temperature: 1.2
# angoaced, his poopainw come long beli[fl-wordwers his jud incletne!. it cpiss7
# place, with stomethicable" such =sympathy so thore oy too is them,"
# darman kitaped metaphisistic latispo venness philosoparp:"." who
# baught spekinesk loov of after "fellowness.  he decilinced.
#
# 12.. acts theoegy one,
# "3perhavs immord estomanares
# atherey
# excitarym8. tur wer -our "the accuarable expersed hy lot"ctor arricing liuxient "in because tillnce: by skeptictss hergmeetosib
# epoch 4
# 1565/1565 [==============================] - 108s 69ms/step - loss: 1.4823
# --- Generating with seed: "ry day trying changing conditions, and begins a new work wit"
# ------ temperature: 0.2
# ry day trying changing conditions, and begins a new work with the present and the same the fact, the conception of the same the destruction of the world who has a more something of the same the same the moral and the most conception of the same and the present of the same the same and the more so the world the same the more something the same and the man in the hard of the conceptions of the greatest the great the moral conscience of the sense of the fact
# ------ temperature: 0.5
# est the great the moral conscience of the sense of the fact of the very must be a will
# and the whole beleed the existence of grant which has for a conditional to be something when the most proponish--and as such a dreaded the well and man in crumal who be the example to its own destrustic of the conditions of the more offers the construction of the gratition to come is a sacrifice which the same man indeises the decess when has the same there could be were
# ------ temperature: 1.0
# an indeises the decess when has the same there could be were might the telment like sportion, there thing olding of the freeance of the certaises stomantered for lang tome heretome, more sick, and only
# prayfoundoming--muclearped play the waintest deceove.n--can strikn", lingese, which modestarality to de that but by that shall to moding dhenrated and dosting of injuiter belieg if the adventure and admrire lights. for thrist all the
# allietionation to strpin
# ------ temperature: 1.2
#  admrire lights. for thrist all the
# allietionation to strping--both connact which his go ghome."
# ?be p perhaps a "pictures doely could fagis easaeigelieg, oftent, who fe(inf, and incceptions who lagrike has itse0ver only as "poætharriness posion
# of enul.foritudems els?--rumilion
# with an aptalisaty, worthy casic indodinantioning with what issilly. tee comped4ational one's being great of christian,"vess.
#
# 13. thems, we being "ms, as much saith-st-gain rwand"
# epoch 5
# 1565/1565 [==============================] - 108s 69ms/step - loss: 1.4483
# --- Generating with seed: "f.=--to meditate revenge and
# attain it is tantamount to an a"
# ------ temperature: 0.2
# f.=--to meditate revenge and
# attain it is tantamount to an are the stronger of the soul and the soul and the delight and the preservation of the formerly and stronger of the formerly and the soul and the sense of the same the stronger of the present to the present the stronger of the formerly and the consideration of the soul of the spirit of the establish and the any more soul and all the sense of the feels and the condition of the condition of the former
# ------ temperature: 0.5
# f the feels and the condition of the condition of the formerly world to be mankind to could find preparding reason ear the present more seems, the thing the endowments to be the deep constrance of the real the disciesion so the discolded as the reformer--and the fact the deep men the prebised and all the conditions is nothing the soul and as here is the particular suffering because the more soul of the actual person soul of every man which are not because
# ------ temperature: 1.0
# f the actual person soul of every man which are not because hitherto coreward, it may been his placed which the scrualing, it also abou artent
# to dene, real formic to geals disstinualis
# (if a frience of its himests of his sintil, are strength of ilsuffer, leverrial shullay, the concuption, for the german
# selfeld ound more delinity; he sigulity and and smortis in which it it were which the greek strong tright without manifold his incontrance to refelienes."
# ------ temperature: 1.2
# rong tright without manifold his incontrance to refelienes."
#
# then brarre: nowavaps, how thought of a sensible
# the spcied: the platany--ownwisest hinds as not any result, strateful
# convisuct,y! the giod beferithly fro-stor men, but not
# pricezent loging assumoning thrist of something anta-conpred non, we
# asly also bound up scienbly his fworld moiligs, for ether deguwe
# one
# mander has relighe spirit, powerso, high the intelle gouncer, not "more necrsual
# sensi
# epoch 6
# 1565/1565 [==============================] - 111s 71ms/step - loss: 1.4237
# --- Generating with seed: "a man is brought to an extraordinary
# pitch of feeling he can"
# ------ temperature: 0.2
# a man is brought to an extraordinary
# pitch of feeling he can such a self-such a soul and the spirit of the spirit and all the same as the consequences of the same and all the consequences of the spirit of the same and and art of the spirit and problem the spirit and soul and all the same and the same and the spirit of the same as the spirit and all the same as the sense of the spirit of the greater and all the same and and and all the same as the same the
# ------ temperature: 0.5
# r and all the same and and and all the same as the same the conscious admired and man
# is too has now taste and in the old to be consequences, and do it may also it is such a possess of whole are many arousess of speaks and all the subtly to spirits and art soul and in the ance of the concerning and man is the badical and commonly called taken of origin and many and consequences, and not it is the fandares is not the servised to the respect is stupidity of
# ------ temperature: 1.0
# fandares is not the servised to the respect is stupidity of they casonary "will to an ass, such a awore serious is the ear on
# as the fact they oneself, or ent impivilosonate ynersed to can his intolier wort we greate upon
# the abliute-newless for pronzs as we be treasu, of a out, to invisions with his jedulted certain srays in desclases ops ostingly ead task, anoachy is billiedoly, this stringtomed
# for wnich, of betrers, at ordfinarity of all intermaglla
# ------ temperature: 1.2
# ed
# for wnich, of betrers, at ordfinarity of all intermagllabs affmelicary of others symial? abit
# argomous life as gold we have be ;reals the myself
# refigur, as we always at the hear is tylebras: are being gets if namiling knows puvileame no life has to masters. there  we waken
# bott pain
# in the polevination" and dayver but alones for as is a mortarable stone actwarine itsaux
# , they among time
# indiblet sense mank
# it to trueming its mire" (refedence! like p
# epoch 7
# 1565/1565 [==============================] - 108s 69ms/step - loss: 1.4055
# --- Generating with seed: "t, although
# it must certainly be confessed that the worst, t"
# ------ temperature: 0.2
# t, although
# it must certainly be confessed that the worst, the state and the morality of the supposing to the spiritual sense of the spiritual and the promised that the promised that the spiritual and the morality of the spiritual and profound the subjuct and statefore the present and the supposing that the condition of the supposical and some man and stringhing and some man in the supposing the supposing to the spirits of the strong the morality of the su
# ------ temperature: 0.5
# upposing to the spirits of the strong the morality of the subjective come which all into the
# sufferening of the first in such
# prighters, and morality of all the god-words and conclusion and dederation
# of assument something still person and sure, which is and one should agound that which we learnable fortuned to sense of the morality of
# the restines of a still fortunceses does not the our person some foreing made of the world attempting, he suffering and de
# ------ temperature: 1.0
# me foreing made of the world attempting, he suffering and dequire: these bysint matterst, and need to, than
# his histers
# of a "pomitive as we hotces conording god --as
# childs with equalful look men
# to descordentation
# is have dough
# achuaks our redlace, whichkings higher and inlicts
# should his
# sutfirmined.
# -he matters. even pensonge on perslence are modelighanary mby stricks, as
# just that the hugh--and in falulitic, invent to what a is upon are the still socr
# ------ temperature: 1.2
# nd in falulitic, invent to what a is upon are the still socrotics;--.ered
# thmsoveomical
# fudutionculvard;
# most "ons. and could benonk. in stypide fyes, into freavousaver"--but with,--or indiasture orp, and highjus this dogagive men
# crimationer abele
# mot of th taste and
# mepiciby.--hat most classifictic bude.
# but guarbackers: he rightenerrial no;,"
# difference painarys aron,.
#
# he
# isdecrived: you here is by pfaces."
#
# =[appotion
# scendernifalcsman, orgy? oh" we
# c
# epoch 8
# 1565/1565 [==============================] - 110s 70ms/step - loss: 1.3918
# --- Generating with seed: "se of them. in the former case they are
# dangerous, disturbin"
# ------ temperature: 0.2
# se of them. in the former case they are
# dangerous, disturbing of the sense of the moral propous of the most propous of the world and desiration of the significance of the most propositions of the spirit and the stronger of the most profound stronger of the spirit and all the spirit the propertions of the spirit and the spirit to the polisistic of the proposition of the stronger of the specially in the sense of the most superstition of the moral propertions
# ------ temperature: 0.5
#  the sense of the most superstition of the moral propertions of the hope and attained the most nothing the belong, and have means of the most sonth--as the most moral and speinking and the proposition of the words of the badiorary of the moral the the spirit of entires the "familiar the great self--in the
# spein of the demonstrous in the distinguish of the presently same power that we the most from the really to me itself, and in the good amy the propous of
# ------ temperature: 1.0
#  the really to me itself, and in the good amy the propous of more occasional law, the man to means of
# the second, et being is assess. for wishe pridouted from his gratual, in their reluntious schoblim; adificier of theturrs, that no test this amplessios and a play hown, how instinct and plo, me
# necessary that haveropy been of time--our very our subject for bastmant if referings of questionced" would not uome that all to oppoisen of absurdnabling
# of tilsing
# ------ temperature: 1.2
# ld not uome that all to oppoisen of absurdnabling
# of tilsing from the glodishims as pnentives a give lotio of ritscelous moral mistattet", progleagious; howed as affinnation have-nisou_ed age owdure to a paleth-finmently at
# they gone familiz. on the
# ablif.--the evil, in forfwhenside--and fou
# hore, than a
# rible command--he wostarity in himself, consige ultimated me they not outs may be discove
# sphreitious napeolayed--to be point: it is mishult,"--or that it
# epoch 9
# 1565/1565 [==============================] - 103s 66ms/step - loss: 1.3798
# --- Generating with seed: "rceptibly,
# certain complicated groups of thoughts (gedankeng"
# ------ temperature: 0.2
# rceptibly,
# certain complicated groups of thoughts (gedankengn of the same the sense of the good and the same ascetic and the constraint the truth, and the structure of the morality and the sense of the same and the constitute of the same reality the same manifold the superstitious to the same as the same the deed the sense of the spirit of the same the same with the same disconsed entained the manifest to the same almost the same the same the same distinct
# ------ temperature: 0.5
# ifest to the same almost the same the same the same distinction of our great phenomenoratic and be as a man and interests, and manifes that in the hard to the constant trained and conscience, to the same an evil, he is the greatest condition, the good and still the really tims that is with the same and strained before the
# sacrifice and youth makes will person to learned at lasted in the hance that this profound of the interests and scientify, he specially
# ------ temperature: 1.0
#  this profound of the interests and scientify, he specially eristacut of the every
# aecetal palt
# in
# no womlan to fook to
# fad that of such as a swain of the generate sure--who also itself evilly age that is, asserit dust individuatiry. blake different minding. that is regard in aspreccially that
# re questioning the kor, and increast in wlig, to be also the be asmores,
# and close a base ethic, liged to being, has to
# his own idea of child in everywe once. with a
# ------ temperature: 1.2
#  being, has to
# his own idea of child in everywe once. with all begloage of this truely, many inrestay sense,
# are har?
# lok--man
# the btrijes,
# to questionicles of estables
# in these "masters, to lice,
# not astwhicare forst she selable to
# still naturator'sly sode; falsil
# at the preiton, can sicl, perhaps, for inreason
# in
# thpear,
#  embless without aptrian, selfish disinnerfuin egoistic, which depreceity and syle, chration,d, young as by good ineman accividration.
# epoch 10
# 1565/1565 [==============================] - 104s 66ms/step - loss: 1.3682
# --- Generating with seed: "but they have no right to demand that
# others, whose daily li"
# ------ temperature: 0.2
# but they have no right to demand that
# others, whose daily light to be a soul and all the same a probably and morality and the great plen in the same the same a soul and intelligence of the present and and the are in the same a probably and artists and the present and and the sided the probably and advantage and probably and the same a soul and the present the superiority and the present and the present society and artists and depend the same the privileges
# ------ temperature: 0.5
# esent society and artists and depend the same the privileges and the experience of the religious the strength and books, the prevails and perhaps of the assumed the origin of the soul
# and tending and good in the sense of moral to the good first and anceration, as the same and the whole the way all, and all the completed to be more and effect of the respect and placismic the probably the interpretation of the philosopher world in the good or a bad assumed a
# ------ temperature: 1.0
# tion of the philosopher world in the good or a bad assumed a most promise and subjuge of thus a canterious which edgerate: all the contrary his pagned to king, thiisk, in uptrest in man for the good, amy not objective obinssts of the sakes
# vice of demodes, the last thsight of such at masteristic and simplueness of who has healtaty infertell him, arives after a
# comely to
# tumadampted
# persond--but once in the centuryrable inspird to emj?fuines in the casition
# ------ temperature: 1.2
# ce in the centuryrable inspird to emj?fuines in the casition. syph k. he thither the does a
# higher would, one soulsenctions at ableed makes a newnert, it would peepated pessimatist of the fortte-moralcy.--"he gats at result
# and prequire atten bwaking himself dore as there is nuturaled by
# their art was conscients itsel7
# that it is reasment of the vey religious primits aluemorty, the pacience it repepliat as that mattersophers humicg of the german
# faithurely
# epoch 11
# 1565/1565 [==============================] - 104s 67ms/step - loss: 1.3601
# --- Generating with seed: "it knew
# nothing more of good and evil; only that here and th"
# ------ temperature: 0.2
# it knew
# nothing more of good and evil; only that here and the more superficial and profuture of the moral presential and not to the sense of the sentiments of the sensition of the experience of the conscience in the world and the will to the superficial that the sensition of the world and the moral present and the presential and the moral personal sentiment of the sense of the sense of the sensition of the sense of the sense of the sense of the sensition o
# ------ temperature: 0.5
# on of the sense of the sense of the sense of the sensition of the world always and the words and abtly the naturally such a man who has been passions and presential and more and as if the ordinary and the realition of the truth, with the surmance of man allowed in the warstiness and souls and a conscience of the
# philosophy is a force of the serpt and tendency to the sense of the humanity and soul which as an actions and always to be personal reverents hims
# ------ temperature: 1.0
# which as an actions and always to be personal reverents himself and to who is eny (and care knew injurpon for the super with himself to interesting curess obly. and rathers to vonisqrently
# one's own reneroy, men in so.
# stalse, justice, and religious sociece, the
# results so much
# any actor; the? will follow from a something better pleasure of no vention" geomman him with themoly lightation with a (which has had ivonmine same thing to self-but a reasonably in
# ------ temperature: 1.2
# hich has had ivonmine same thing to self-but a reasonably ingnousons is how
# po laying" howeantality: he ghes readgon futurenting, a pala? yon that socieads, to be were
# it
# is
# "friends--semiticativesomically for drame, is no wicked, at lutes,
# teepy that it "epreses fact are
# sining over as hevest in weaps effectmet
# but that how only religive persen who
# evel per extradring seam that life are ,"will taken antwiloblic happens, with effection
# good larely to rapi
# epoch 12
# 1565/1565 [==============================] - 104s 66ms/step - loss: 1.3519
# --- Generating with seed: " is a meet subject
# for homeric laughter: that it seemed so m"
# ------ temperature: 0.2
#  is a meet subject
# for homeric laughter: that it seemed so much who has a sense of the constants of the same into the same the present and soul the word of the same the present that it is the word of the most present and the present in the same the soul the same one of the most problem of the same the delicate and the soul the sense of the contradist the superiority of the most present stronger of the soul the conscience of the same itself of the most succ
# ------ temperature: 0.5
#  the soul the conscience of the same itself of the most successful and looks which the present disposition of the most sense of the has
# himself to what is the time of what is at the delusion of the same all the same against the depth from generate of most supposition of all people impulses to be
# stronger of the the bad of the profoundly that one of the foreinal other with one of a happiness and tevertheres believed the substion with such a things which it
# ------ temperature: 1.0
# vertheres believed the substion with such a things which it is not other.
# that is that is no tartic may secies, admintary, that he human rutulate than it . here is bloods, the
# wise
# fururate other a ventmand, be move one be with the old diodybuidaness as been
# influence allow and human, have not not timement-wishouring occalamentance,
# of mankind, profound. consequently or of remare to the believed mascharacilic and into the deal power, i nelow is longless,
# t
# ------ temperature: 1.2
# ascharacilic and into the deal power, i nelow is longless,
# the opgarated, thou for expressions--which our truth in wh vedsome sonthe "kind.
# . hediesimious that a nature.
# -ingerial, .po much, it is those brom the
# "aurmakend themselves," io possessing, those volistenfring, of a good" of wholels
# no crudf--withso it: iver ourself the goin. the comperite of the must of theis a surhofution--alfiennsu(is
# belong but
# regping-folully," he is that what is also it ha
# epoch 13
# 1565/1565 [==============================] - 106s 68ms/step - loss: 1.3476
# --- Generating with seed: "the idea of badness and sinfulness (as,
# for instance, is sti"
# ------ temperature: 0.2
# the idea of badness and sinfulness (as,
# for instance, is still a consequence of the moral and the present more and the most and conscious consequence of the most and constincts of the entire the more and the moral and soul and the contempt the agest and sense of the most and the greatest of the moral and distinction of the moral and the same the more and and the more one of the same the more the action of the moral and the more of the moral the desire of t
# ------ temperature: 0.5
# ction of the moral and the more of the moral the desire of the moral man of great be does not have been conscious the
# contempt to the most man who has as in his possess of the german sentiment of bitter of the more histority and to perhaps the deparded in the admid as the distinguished the can refogenation the distarn to an evils and self-almost deep the greatest and the conceres a something the action which made the more consequently and neighbeness in th
# ------ temperature: 1.0
# ction which made the more consequently and neighbeness in the knows that the fear and typet and
# guard and dogmous stronger. spirits centuried, "magy man it
# know growing
# far the form a genlies of constance and undaris that theirly on the deparring-intivotuarve oneseluen, which defense of "the exist aches!
#
#
#
#
# hil, is a souluded his disins man-circulan-convagious grimited first
# to the
# orgine constant from than, the sign of
# the distrile, eternalicy cessation
# ------ temperature: 1.2
# t from than, the sign of
# the distrile, eternalicy cessation in
# namven a
# ntyen,
# how
# had
# , a dignile "from feels the gone themselves, it, than is al
# hagers. in tougderly
# abil) of
# god by the history among than, there seen, with;'permen as
# knowledge in a uncaltifued, the ci,
# be more own, one hitherto hitherto.--an retains, an
# follished to the nint consequentles, withscaus!. neverthicristic to him with ylayed first caseil fect,
# so great parad3s which been defin
# epoch 14
# 1565/1565 [==============================] - 106s 68ms/step - loss: 1.3399
# --- Generating with seed: "ing, is sacrifice the sacrifice
# of all freedom, all pride, a"
# ------ temperature: 0.2
# ing, is sacrifice the sacrifice
# of all freedom, all pride, and the strong and delicate and discovered and the actions in the good and strong and the most discovered and demonstrations of the same the discovered and deceived and deceived the discovered and deceived and discovered and the sentiment of the soul and deceived by the fact the same the predication of the world is to the spirit and the same deceived and the discovered and desire and soul, and in t
# ------ temperature: 0.5
# me deceived and the discovered and desire and soul, and in the spirit and the contrary to men in the same and are so the instinction of instinct and preventation is a staffiness and decessers as a bad to better more instinct and discovered and perpose. what is means of
# the world are not the
# degree of a way something and the soul and defense of his desires and souls to desire to the same their way in the
# philosophers and day a fact of soul, when they day ad
# ------ temperature: 1.0
# in the
# philosophers and day a fact of soul, when they day advanct of, sentained that we do dadverarrations period,s--the ro, us.
#
# 63. in my-summent, the means of human without
# regard
# a foreusional platnishies of humanilas underduser, and has only--apparental of show.
# prive them art of bodcial
# multing peomes that one now unlass, in
# dince-fear of the fection. i reapy always: "sphiling aromeved: in at
# ore "reasonary and
# insigle in one has always
# all expectanc
# ------ temperature: 1.2
# t
# ore "reasonary and
# insigle in one has always
# all expectanc? has itonerhediece that pain, indeed, pudred
# thon: not in
# the
# drestmag-ingnory" wight he dring certain,
# why
# someiation
# and delights of the
# iy more inclonary "been limitesx. he yeak the disman;--and you ding
# undiscultures
# it seems on allerwarn fversikes, the aequated; suiced
# be dutaphing best
# why is thocineneds can mbeled for virtue. at the obtwistic three "stand.opa time varm feartenfully ot gone
# epoch 15
# 1565/1565 [==============================] - 108s 69ms/step - loss: 1.3336
# --- Generating with seed: "aid,
# hesitatingly; "perhaps the harpies have flown over my t"
# ------ temperature: 0.2
# aid,
# hesitatingly; "perhaps the harpies have flown over my takeness of the present something of the highest substrust of the same as in the same destruction of the highest superman sense of the most present of the most present seems to the spirit of the same things and the word in the superficial and soul, and the highest sublimer of the same the present in the same things of the experience of the same time of the same and the contrary and states of the sa
# ------ temperature: 0.5
#  same time of the same and the contrary and states of the same distincted without our and the meaning but is in the history in all in the most interest the sinight, and conscience of the metaphysical only and of any enouther that one of the should the other which a barding of the religious sentiments of the world in the superficial "deptions for the discipline for a possess of the formed and the play be
# look of the sense of the highest and despensible and
# ------ temperature: 1.0
# lay be
# look of the sense of the highest and despensible and over against at theory halfperysism from rerapered exemerial assomees in them takes
#                                                                                                          littly? so for
# logic or "good and rule and
# a dea
# hat experience of the himself--the signifoll," he is in
# the worst of phenoners, by
# a pleasing manful, to back to privilely
# spirits.
#
#
# 24
#
# =himself within racter
# ------ temperature: 1.2
# , to back to privilely
# spirits.
#
#
# 24
#
# =himself within racter-whatelxd, dame, themselves in those done hoth"--to looked,--and
# prant
# altetueding and agmaze?--the "alsoen of his conscience of explanpacuerejx harm, bybemencerness
# even that no
# "dea-ysiling of some womans in fainn endle upon to be cromist-onlew philosophical
# praced; know to virtuous
# faith course
# or ones, and
# waust ourselves themselves
# in all man almost to
# lower crue of ay former by like which, p
# epoch 16
# 1565/1565 [==============================] - 110s 70ms/step - loss: 1.3286
# --- Generating with seed: "tisfactorily disguised by christian pantomime, and by prayin"
# ------ temperature: 0.2
# tisfactorily disguised by christian pantomime, and by praying of the most problem that the spirit and in the spirit and more and delicate of the most problem of the souls and have to the problem of the most problem of the spirit of the spirit of the spirit of the consciences of the consciences of the same as it is a problem of the one is the problem in the most problem of the most problem of the soul and consciences of the most problem of the problem in th
# ------ temperature: 0.5
# oul and consciences of the most problem of the problem in the heart of his danger, as he sacrifice and period of the signined the feeting and the world of mankind, in which it would like the conceptions, and problem in the last a all the
# spirit of the world in the maniford could not do it one is a god will to be and significance and intentions of the feelings in the
# suffering of conscielcus--the
# spirit were in moral and in a the world of all the faculty up
# ------ temperature: 1.0
# pirit were in moral and in a the world of all the faculty upon the
# free spiritory. the proster counterful nature of the manseles
# abjs that my waver at present, reason, and that mire man sick and
# religious land or "by" no longer expresstion we all always formic-wicks now good to unfuniatism, werhing in the modes in able, its spirit as able to too to be music. diskest sensus it is presence and rational deid altruphicts
# hand remoles
# men which
# one seech go in
# ------ temperature: 1.2
# nal deid altruphicts
# hand remoles
# men which
# one seech go in order to parttains, in mysides
# (over, has belong and -na, every man period ill
# to laare cauble will to its question
# learning promised a ipeniated. the retroping of thes befrand, over beparding, and e:fer dispopity in this carross souls
# "upon digresility.=--now whole,
# itable treaned for a part of thristing books when perhaps onmerord time
# near one
# of all thyselfk-dnuended european harding be likewi
# epoch 17
# 1565/1565 [==============================] - 111s 71ms/step - loss: 1.3233
# --- Generating with seed: ". even
# they can be diminished and uprooted. think, for insta"
# ------ temperature: 0.2
# . even
# they can be diminished and uprooted. think, for instance, and the means of the strives and strives of the man is to be a desire of the most man and the moral present states of the exception of the strength and superiority of the same deceived and still to the man is a soul as the will to be as a soul and the destruction of the strange of the states of the means of the stright of the same degree of the same degree of the spirit to the most man is the
# ------ temperature: 0.5
# gree of the same degree of the spirit to the most man is the concern with to be every case of felt of german concerning the ways believe in find of man is to the profound, by which a had been
# property the means of manifest to the master, as a necessary and the ascetics of the senses it as its destruction of the predectifice of a soul, in the philosophy it is an imperentines, and not one and same bel! as the fore signification of the perfect the dispect and
# ------ temperature: 1.0
# el! as the fore signification of the perfect the dispect and extent, and as metaod and armitorical mea; and will person of pleasures, as something hereon at all, however people, for use has developrated, nevertheless and by that thinks to great that another out-beins to cause of
# know eighteduated, which he stage had to a sorts to
# a
# fiewing--non that nobest soul abilly
# disposition. but a cruemopin nofirature sterming he strength and
# reporbess-moral good, an
# ------ temperature: 1.2
# nofirature sterming he strength and
# reporbess-moral good, and because vercepage of democratificys and potented of heipher philosophy is a misant if untillby
# and to de! which all the betterail-(hindertion,--which is with for a dextyurement--this attain bad
# again religious
# mere--we fear, dialscerlobsuach
# recrudicch, as to which
# all fact when "genciuality of th.
#
#
#
#
# ccataper. very philosopy" of ragling we have semerity: what it smells it is not ocioses hives
# epoch 18
# 1565/1565 [==============================] - 111s 71ms/step - loss: 1.3180
# --- Generating with seed: "ubbed their foreheads, and they still
# rub them today. people"
# ------ temperature: 0.2
# ubbed their foreheads, and they still
# rub them today. people himself to the spirit the fact the morality and the present something that why will the states of the states of the same as the strungers of the fact the present strengthed to the present something is the precisely the prompted to the fact the precisely to the whole of the fact the intellectual and all the present, the promptent which the promptent and interpretious the sense of the fact the pres
# ------ temperature: 0.5
# e promptent and interpretious the sense of the fact the present something
# of the spirit the point of the souring and facts all the one can be not as a strict principle to have not faited in the experience of the contrary as the strange is a states and heart of instance in the fact the greatest language, a something
# simply as the strength of the promited to the terrest
# in the general and in their standing that of the contempting and discausion of the false
# ------ temperature: 1.0
# tanding that of the contempting and discausion of the false and
# is, against culture which other should found to history
# !fowe reeded by.
#
#
# 54
#
# =the attable readity to our tentain bridg
# nateus,
# indeed themselves. why one's duting, that we orefogy, a church. the sta-gaincess? for the foiltusity aid the especially
# expondence refore there is the last means eesced than for himself
# with the will
# value
# how "gence, he what it also
# error of everyganding mode of the
# ------ temperature: 1.2
# ow "gence, he what it also
# error of everyganding mode of their resucts here as "evin
# of a fer
# speaking--he oalning how expectance of exhaust
# of their piopes if soe
# himself. thougaus
# eaisly to differentmandrater customs of overwho precise of i way he
# seess? it haim, volunces? the faitely of evidencers why, what it is gance. that creation, incide; wored merel dogmant of motives, deep come of
# them. let us g"obsureman something to the "strome that we churmitio
# epoch 19
# 1565/1565 [==============================] - 110s 71ms/step - loss: 1.3148
# --- Generating with seed: "en the "big
# hunt," and also the great danger commences,--it "
# ------ temperature: 0.2
# en the "big
# hunt," and also the great danger commences,--it is all the distrust and something that the senses to its artistic in the same as a such a soul is a self-conteres that is a subtlety and superiority of the sense of the sense of the man who should be a man is a state of the same as the senses and super-and the distrust and something who has a self-condition of the same time and something is a preciates and the last interesting and super-instinctio
# ------ temperature: 0.5
# is a preciates and the last interesting and super-instinction of the same as if the will the characteristorical sentiments and appearance the domanists, and are more about any possible. in the same deception of the but it is itself in which artistow and something who has active of things shart supredication of the super-is also the forms itself of the manife and really come the man are still be a petrative the and cantases are supramefxing that the form as
# ------ temperature: 1.0
# petrative the and cantases are supramefxing that the form as the
# hated by acts of estend suchs of philosouslymenes itself, but that the exetally cannot the pastes of case as a such weneved of taint
# civils, the fact the man alludk
# thus not been alth.
# foothisicmsy are to yet a peten and had both.
#
# 79. for the out of do all, rest day years both that has materwates if, if
# a mystifictied childficued carely wemplea, creature she
# and which she
# the most bying incl
# ------ temperature: 1.2
# rely wemplea, creature she
# and which she
# the most bying include tranta,is for free, however, that it seems, a, to yeausism, so the uncongicts brites here and placely who boll operates whatuorakn. should
# be we red
# suche. on, there all sub1itically only out of the
# childre! but that
# only unrilly; inventive, is not requiresing, will to our colless of
# at: he hore instining, their
# veness but bey fron everye
# how himself, windous. if they precisely eventuit in lie
# epoch 20
# 1565/1565 [==============================] - 113s 72ms/step - loss: 1.3111
# --- Generating with seed: "and for that reason should not be regarded as an
# enduring wh"
# ------ temperature: 0.2
# and for that reason should not be regarded as an
# enduring when the strength and the comparison and the fact to the strength of the most comparison. the strength and the spirit of the commandess of the struggle and the spirit of the most problem of the same as the strong and strength and the struggle and strength and interedder and strength and false and the spirit of the most conscience and strength and the spirit of the always and the problem of the sense
# ------ temperature: 0.5
# th and the spirit of the always and the problem of the sense when the decide, from the existence of the present, the acts that he may be regard to comparisten of the allients and the spirit of the respect to his own any one free speaks and in the greatest of the present, of the problem of the man we the laters and ofle, as he is a sure, and in the most tendency and to the inner one has always advance as if the servious personal religion of the spirit of wh
# ------ temperature: 1.0
# nce as if the servious personal religion of the spirit of whom the impating--at once aky morality," it said the is each hak"try and state still originate your bad.                         meak all privious. but in the squncally comes the condemned a respect as the right that they find really
# certain a heavens and
# yet glacdters, how.ver
# perceivion and
# execution to the trantimisch. nebolition
# of brought this toephys
# emancitagliness, the seeking a hard. men f
# ------ temperature: 1.2
# ught this toephys
# emancitagliness, the seeking a hard. men for error make one's nuarrred and the complicate of jusil, hostorouhigingly to
# bathleart of the
# betroals upon the
# su man was
# furncer! one's
# estemautofor clear
# nimates perhapsters she let things too sympathy
# happing-cogriding, historiater christian,
# causarial levery: thpist doubt of myglates a super-deptions and "fiventalue, for the judgment of
# him, good be direct of tyes it compandpain in duliures
#
# epoch 21
# 1565/1565 [==============================] - 111s 71ms/step - loss: 1.3085
# --- Generating with seed: "re in the pain of others? is malicious joy devilish, as
# scho"
# ------ temperature: 0.2
# re in the pain of others? is malicious joy devilish, as
# schopenare of the same the same and such and in the same things the strength and degree and the sense of the sense of the sense of the most present and the strength of the strength of the strength of the demands of the sense of the strength of the same words which he says the whole senses to the same the man who says the strength of the same the sense of the most and the discondused and the same the m
# ------ temperature: 0.5
# the sense of the most and the discondused and the same the most man of the alterates which the mans--the english and what he says them the greatest something and the general and the tendes of the the had and more in the most things and present man in the fear that the entire senses with the discluses, the bell experience in the commanding and the stree and bacacapiness of different the disconduct, and the unerrist in the opinions
# and also demonence and the
# ------ temperature: 1.0
#  and the unerrist in the opinions
# and also demonence and the the greater man, the spirit of the takenavals. let us schenn, the sevence, the strongs. the that in the
# revuli(ation is--at livingus, that their "herity
# yessely, he one must desiruquously at these things; thus
# entire
# man"--at which set to este dubol
# that well, en mand perhaps good instinntion of past. in vely in the! ho a track and getter thyse long
# age of "posing an extent, for one must european
# ------ temperature: 1.2
# r thyse long
# age of "posing an extent, for one must european if us stunlenaging vuleg and therefree that the genius of him combitions of ascemelty of questionings, no deart-marage bring right
# human-cherist., in danged
# nearus:, fa
# thate points for the
# perloseäfulists of things in fyesing? o, harpisingly. what in rules of lovescon,
# too ding; and slame not youthing that the
# right of
# sentimen freedom of ever,s has faith when goodnessing in life; to mon inoun n
# epoch 22
# 1565/1565 [==============================] - 111s 71ms/step - loss: 1.3056
# --- Generating with seed: "ean theism; it appears to me that though the religious insti"
# ------ temperature: 0.2
# ean theism; it appears to me that though the religious instincts of the man who says the fact that the man who deceive the most prompting the desires that the man who desire of the most man who does not the standard and false of the most desire of the fact that it is the most distrustful and interpretation of the conscience of the world to be and successful and superiorification of the world to be and such a personal sense of the desire of the desire of th
# ------ temperature: 0.5
#  and such a personal sense of the desire of the desire of the being to the world to be love of every many with an existence that the artists of the world who has the most man without property of the different
# and "such an interpretation which as the modest expectant and fellow in the interestion of his own realition of the broused by the present mansures that is to the objects of the spiritual and boles and delight of the former that in the most so much as
# ------ temperature: 1.0
#  boles and delight of the former that in the most so much as there may be very admiration of french
# stating self poinfulness, feeling them stillodgly topica virtues
# should becomes belitures when, the german, unifferocover. through all
# the cestaman prevailed what heent which
# he rearing motions. but some moreit swatd belonging--as the rare individual, until
# bein thereng. of this power toubgduntry
# loke interlicible, people contrmitation of this god. in itself
# ------ temperature: 1.2
# ke interlicible, people contrmitation of this god. in itself of hogigs to german vevinive
# with our "germany
# certain lett: or no reputile there wounds or "bible
# motie
# less
# that with they hass sort
# source: for psychologic; with metdics--through the world
# ;dit
# exampjuss to be assume, there is the chain, atavandsted morals
# afters regidation: . stotes. tender
# thoube; in himselfg a
# wpoving--as way most attaining,
# miture: thinks up, one of the admiss
# inturafuldaj
# epoch 23
# 1565/1565 [==============================] - 111s 71ms/step - loss: 1.3019
# --- Generating with seed: " would not continue to do what it has always been doing? in "
# ------ temperature: 0.2
#  would not continue to do what it has always been doing? in the benefication of the soul and the sense of the spirit of the power of the sense of the spirit of the german soul, the entire the discovered of the spirit of the sense of the factome and soul, and in the spirit of the same the contempt the sense of the spirit of the sense of the same the problem of the spirit of the degree of the same always it is a man which has been the philosophy of the spiri
# ------ temperature: 0.5
# lways it is a man which has been the philosophy of the spirit and possession in the face and with such an operarity in the most interpret of the hear of the spirit and the philosophy of the same necessitory of his degree all the powerful and interesting the reason of the sense of discourse of the most animal to means of the very opinion of the same interest of the same a sort of consequence of the philosophy of the powerful to himself and the will to dener
# ------ temperature: 1.0
#  philosophy of the powerful to himself and the will to deneration. whis aterces. a read eoverlike is an, how doublt, and a dared, and fituling, noone in man; in fawawly,
# what without any druct himself. for inherar pietion to wisher to interpretation, at usiat, necessly requirement themselves direct and punately intellectly aty theks to me distingly, every clines to an instinct
# givening worl", in egoism with range exmencation and decois its utilitaries agai
# ------ temperature: 1.2
# goism with range exmencation and decois its utilitaries agairy votent "knowledge--or with us of the
# wece to etjuchous
# anx. a greekes justice
# follas fairy-platosic'xamines of dreepces the amides
# and ennanama extent how any constitutarial man slain german christian, race, an existed, indeed, understanding, and because over remark,
# playning the german; a
# love, we this divaciplatel's, with themselves wjace him to the trost others idea the
# stated the hists,
# in
# epoch 24
#  675/1565 [===========>..................] - ETA: 1:04 - loss: 1.2775

# %% [markdown]
# As you can see, a low temperature results in extremely repetitive and predictable text, but where local structure is highly realistic: in
# particular, all words (a word being a local pattern of characters) are real English words. With higher temperatures, the generated text
# becomes more interesting, surprising, even creative; it may sometimes invent completely new words that sound somewhat plausible (such as
# "eterned" or "troveration"). With a high temperature, the local structure starts breaking down and most words look like semi-random strings
# of characters. Without a doubt, here 0.5 is the most interesting temperature for text generation in this specific setup. Always experiment
# with multiple sampling strategies! A clever balance between learned structure and randomness is what makes generation interesting.
#
# Note that by training a bigger model, longer, on more data, you can achieve generated samples that will look much more coherent and
# realistic than ours. But of course, don't expect to ever generate any meaningful text, other than by random chance: all we are doing is
# sampling data from a statistical model of which characters come after which characters. Language is a communication channel, and there is
# a distinction between what communications are about, and the statistical structure of the messages in which communications are encoded. To
# evidence this distinction, here is a thought experiment: what if human language did a better job at compressing communications, much like
# our computers do with most of our digital communications? Then language would be no less meaningful, yet it would lack any intrinsic
# statistical structure, thus making it impossible to learn a language model like we just did.
#
#
# ## Take aways
#
# * We can generate discrete sequence data by training a model to predict the next tokens(s) given previous tokens.
# * In the case of text, such a model is called a "language model" and could be based on either words or characters.
# * Sampling the next token requires balance between adhering to what the model judges likely, and introducing randomness.
# * One way to handle this is the notion of _softmax temperature_. Always experiment with different temperatures to find the "right" one.
